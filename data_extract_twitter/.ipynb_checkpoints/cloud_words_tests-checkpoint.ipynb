# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
import re
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
import nltk 
from nltk.corpus import stopwords

nltk.download('stopwords')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /home/julio/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords = " | ".join(stopwords.words('portuguese'))

# %%
df = pd.read_csv("./data_tweets/persist_tweets_2021-03-07-19-13-24-863807_2021-03-07-19-27-29-932784.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                   id  \
# 0           0  1368686198525411328
# 1           1  1368686196185067528
# 2           2  1368686188542984192
# 3           3  1368686185586061312
# 4           4  1368686170432036864
#
#                                                 text  \
# 0  @Sakura21330032 @Josiane78472211 @bbb e por es...
# 1  @bbb Esqueceu de dizer o que ela falou de Sara...
# 2  @egirlfromrio @isabellasena @bbb Oque de ruim ...
# 3  @egirlfromrio @isabellasena @bbb Mulher Gil vo...
# 4  @chizuforv7 @AZNingumStrang1 @Ellecancelada @n...
#
#               date_extraction
# 0  2021-03-07 19:13:24.863807
# 1  2021-03-07 19:13:24.863807
# 2  2021-03-07 19:13:24.863807
# 3  2021-03-07 19:13:24.863807
# 4  2021-03-07 19:13:24.863807

# %%
text = " ".join(review for review in df.text)

text = re.sub(r"(?i){}".format(stopwords),"",text)

text = re.sub(r"(?i)[^A-Za-z1-9]t[^A-Za-z1-9]|\/co\/|bbb21|oficial|boninho|RedeGlobo|globo|gostaria|solicitar|support|reality|show|@bbb|Big Brother Brasil|Twitter|Brasil|https|TwitterSupport|verificação|verified","",text)
text = text.replace("/co/","")

wordcloud = WordCloud(max_font_size=200, max_words=200, background_color="black",width=2300, height=1200).generate(text)
plt.figure(figsize=(17,17))
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()
